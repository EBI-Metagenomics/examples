# %% [markdown]
# # How to combine MGnify Run data with pHmmer sequence search results in a TSV

# %% [markdown]
# User request:
# `After using the sequence search tool, I tried to download the results but the information about the RUNs is lost in the .csv file. How can I include it?`

# %% [markdown]
# The [MGnify Run](https://emg-docs.readthedocs.io/en/latest/glossary.html?highlight=runs#term-Run) information for a search result hit is available in the JSON download data, but not in the TSV file. To augment the TSV with that data from the JSON, we can manipulate the JSON slightly into a table format, and join the two.

# %%
import pandas as pd
import json

# %% [markdown]
# Files downloaded from a Sequence Search result, e.g. https://www.ebi.ac.uk/metagenomics/sequence-search/download/F5AB62C8-19F9-11EC-BD62-FC88FDD569CA/score

# %%
TSV_FILE = '4C6B46DA-19F2-11EC-BD62-FC88FDD569CA.1.csv'
JSON_FILE = '4C6B46DA-19F2-11EC-BD62-FC88FDD569CA.1.json'

# %%
results_table = pd.read_csv(TSV_FILE, sep='\t')
results_table.set_index('Target Name', inplace=True)

# %% [markdown]
# Now load the JSON as a table, and extract the Run accessions.

# %%
with open(JSON_FILE, 'r') as json_file:
    hits_list = json.load(json_file).get('results').get('hits')

json_results = pd.json_normalize(hits_list)
json_results.rename(columns={'name': 'Target Name'}, inplace=True)
json_results['Runs'] = json_results.apply(lambda hit: [run[0] for run in hit['mgnify.runs'] or []], axis=1)
json_results = json_results[['Target Name', 'Runs']]
json_results.set_index('Target Name', inplace=True)

# %%
results_table = results_table.join(json_results, on=['Target Name'], how='left')
results_table.to_csv('phmmer_result_with_runs.tsv', sep='\t')
results_table
# Out:
#                   Target Accession  Target Length  \
# Target Name
# MGYP000006146753               NaN            409
# MGYP000160620212               NaN            409
# MGYP000016395208               NaN            409
# MGYP000015122295               NaN            410
# MGYP000072312189               NaN            410
# ...                            ...            ...
# MGYP000078628186               NaN             61
# MGYP000197530100               NaN            312
# MGYP000197530100               NaN            312
# MGYP000098668621               NaN            292
# MGYP000151931285               NaN            119
#
#                                                          Query Name  \
# Target Name
# MGYP000006146753  >tr|F2BTU6|F2BTU6_STRSA Arginine deiminase OS=...
# MGYP000160620212  >tr|F2BTU6|F2BTU6_STRSA Arginine deiminase OS=...
# MGYP000016395208  >tr|F2BTU6|F2BTU6_STRSA Arginine deiminase OS=...
# MGYP000015122295  >tr|F2BTU6|F2BTU6_STRSA Arginine deiminase OS=...
# MGYP000072312189  >tr|F2BTU6|F2BTU6_STRSA Arginine deiminase OS=...
# ...                                                             ...
# MGYP000078628186  >tr|F2BTU6|F2BTU6_STRSA Arginine deiminase OS=...
# MGYP000197530100  >tr|F2BTU6|F2BTU6_STRSA Arginine deiminase OS=...
# MGYP000197530100  >tr|F2BTU6|F2BTU6_STRSA Arginine deiminase OS=...
# MGYP000098668621  >tr|F2BTU6|F2BTU6_STRSA Arginine deiminase OS=...
# MGYP000151931285  >tr|F2BTU6|F2BTU6_STRSA Arginine deiminase OS=...
#
#                  Query Accession  Query Length        E-value  Score  Bias  \
# Target Name
# MGYP000006146753               -           409  3.500000e-265  890.8   4.0
# MGYP000160620212               -           409  2.000000e-255  858.6   3.9
# MGYP000016395208               -           409  1.100000e-234  790.3   3.2
# MGYP000015122295               -           409  3.400000e-233  785.4   3.3
# MGYP000072312189               -           409  6.700000e-233  784.5   3.4
# ...                          ...           ...            ...    ...   ...
# MGYP000078628186               -           409   9.100000e-03   26.8   0.0
# MGYP000197530100               -           409   9.300000e-03   26.8   0.0
# MGYP000197530100               -           409   9.300000e-03   26.8   0.0
# MGYP000098668621               -           409   9.300000e-03   26.8   0.2
# MGYP000151931285               -           409   1.000000e-02   26.7   0.0
#
#                   Domain Index  Domain Count  ...  Query Ali. End  \
# Target Name                                   ...
# MGYP000006146753             1             1  ...             409
# MGYP000160620212             1             1  ...             409
# MGYP000016395208             1             1  ...             409
# MGYP000015122295             1             1  ...             409
# MGYP000072312189             1             1  ...             409
# ...                        ...           ...  ...             ...
# MGYP000078628186             1             1  ...              51
# MGYP000197530100             1             2  ...             284
# MGYP000197530100             2             2  ...             403
# MGYP000098668621             1             1  ...             407
# MGYP000151931285             1             1  ...             290
#
#                   Target Ali. Start  Target Ali. End  Target Env. Start  \
# Target Name
# MGYP000006146753                  1              409                  1
# MGYP000160620212                  1              409                  1
# MGYP000016395208                  1              409                  1
# MGYP000015122295                  3              410                  2
# MGYP000072312189                  5              410                  1
# ...                             ...              ...                ...
# MGYP000078628186                  6               50                  1
# MGYP000197530100                140              217                134
# MGYP000197530100                217              306                203
# MGYP000098668621                232              291                215
# MGYP000151931285                  2               56                  1
#
#                   Target Env. End   Acc       Description  Mapped PDB(s)  \
# Target Name
# MGYP000006146753              409  1.00  MGYP000006146753            NaN
# MGYP000160620212              409  1.00  MGYP000160620212            NaN
# MGYP000016395208              409  1.00  MGYP000016395208            NaN
# MGYP000015122295              410  1.00  MGYP000015122295            NaN
# MGYP000072312189              410  0.99  MGYP000072312189            NaN
# ...                           ...   ...               ...            ...
# MGYP000078628186               59  0.87  MGYP000078628186            NaN
# MGYP000197530100              224  0.80  MGYP000197530100            NaN
# MGYP000197530100              311  0.85  MGYP000197530100            NaN
# MGYP000098668621              292  0.88  MGYP000098668621            NaN
# MGYP000151931285               73  0.86  MGYP000151931285            NaN
#
#                   Number of Identical Sequences  \
# Target Name
# MGYP000006146753                              0
# MGYP000160620212                              0
# MGYP000016395208                              0
# MGYP000015122295                              0
# MGYP000072312189                              0
# ...                                         ...
# MGYP000078628186                              0
# MGYP000197530100                              0
# MGYP000197530100                              0
# MGYP000098668621                              0
# MGYP000151931285                              0
#
#                                                                Runs
# Target Name
# MGYP000006146753                                                 []
# MGYP000160620212                                       [ERR1474574]
# MGYP000016395208                                       [SRR6231191]
# MGYP000015122295  [ERR526022, SRR3132381, SRR3132143, SRR3132237...
# MGYP000072312189                                       [ERR1135178]
# ...                                                             ...
# MGYP000078628186                                       [ERR2168994]
# MGYP000197530100                           [SRR1628698, SRR1628697]
# MGYP000197530100                           [SRR1628698, SRR1628697]
# MGYP000098668621                                       [SRR3580189]
# MGYP000151931285                                       [SRR6231152]
#
# [2968 rows x 25 columns]
